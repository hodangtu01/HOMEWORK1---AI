# %% [markdown]
# <a href="https://colab.research.google.com/github/hodangtu01/HOMEWORK1---AI/blob/main/W9_ANN_Detection_Face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras.utils import load_img, img_to_array
import matplotlib.pyplot as plt

# %%
from google.colab import drive
folder = '/content/drive/MyDrive/cifar100_tu_w9.hs5/tongHop'
photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('phong'):
    output = 0
  elif file.startswith('chi'):
    output = 1
  elif file.startswith('TUAN'):
    output = 2
  elif file.startswith('BINH'):
    output = 3
  elif file.startswith('NHuy'):
    output = 4
  elif file.startswith('Tri'):
    output = 5
  elif file.startswith('Tu'):
    output = 6   
  else:
    continue
  photo = load_img(folder + '/' + file, target_size=(30, 40))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)
photos = asarray(photos)
labels = asarray(labels)
save('photos.npy', photos)
save('labels.npy', labels)

# %%
# !cp photos.npy "/content/drive/MyDrive/cifar100_tu_w9.hs5"
# !cp labels.npy "/content/drive/MyDrive/cifar100_tu_w9.hs5"

# %%
from sklearn.model_selection import train_test_split
import numpy as np
photos = np.load('/content/drive/MyDrive/cifar100_tu_w9.hs5/photos.npy')
labels = np.load('/content/drive/MyDrive/cifar100_tu_w9.hs5/labels.npy')

x_train, x_test, y_train, y_test = train_test_split(photos, labels, test_size=0.3)

# %%
print("x_train shape: ", x_train.shape)
print("x_test shape: ", x_test.shape)
print("y_train shape: ", y_train.shape)
print("y_test shape: ", y_test.shape)
# Out:
# x_train shape:  (334, 30, 40, 3)
# x_test shape:  (144, 30, 40, 3)
# y_train shape:  (334,)
# y_test shape:  (144,)

# %%
x_train = x_train.reshape(334, 30, 40, 3)
x_test = x_test.reshape(144, 30, 40, 3)
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
from keras.utils import to_categorical
y_train = to_categorical(y_train, 7)
y_test = to_categorical(y_test, 7)

# %%
(y_train.shape),(y_test.shape)
# Out:
# ((334, 7), (144, 7))

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, LeakyReLU, Dropout
model = Sequential()
#training data to recognize different faces, remember to use LeakyReLU, Dropout, Normalization
model.add(Conv2D(32, kernel_size=3, activation='relu', input_shape=(30, 40, 3)))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=3, activation='relu'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, kernel_size=3, activation='relu'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.3))

model.add(Dense(7, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 28, 38, 32)        896
#
#  leaky_re_lu_24 (LeakyReLU)  (None, 28, 38, 32)        0
#
#  max_pooling2d_18 (MaxPoolin  (None, 14, 19, 32)       0
#  g2D)
#
#  dropout_24 (Dropout)        (None, 14, 19, 32)        0
#
#  conv2d_19 (Conv2D)          (None, 12, 17, 64)        18496
#
#  leaky_re_lu_25 (LeakyReLU)  (None, 12, 17, 64)        0
#
#  max_pooling2d_19 (MaxPoolin  (None, 6, 8, 64)         0
#  g2D)
#
#  dropout_25 (Dropout)        (None, 6, 8, 64)          0
#
#  conv2d_20 (Conv2D)          (None, 4, 6, 128)         73856
#
#  leaky_re_lu_26 (LeakyReLU)  (None, 4, 6, 128)         0
#
#  max_pooling2d_20 (MaxPoolin  (None, 2, 3, 128)        0
#  g2D)
#
#  dropout_26 (Dropout)        (None, 2, 3, 128)         0
#
#  flatten_6 (Flatten)         (None, 768)               0
#
#  dense_12 (Dense)            (None, 128)               98432
#
#  leaky_re_lu_27 (LeakyReLU)  (None, 128)               0
#
#  dropout_27 (Dropout)        (None, 128)               0
#
#  dense_13 (Dense)            (None, 7)                 903
#
# =================================================================
# Total params: 192,583
# Trainable params: 192,583
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compile stop when the accuracy stop increasing
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, mode='max')
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 11/11 [==============================] - 2s 32ms/step - loss: 1.9306 - accuracy: 0.2036 - val_loss: 1.8850 - val_accuracy: 0.2431
# Epoch 2/100
# 11/11 [==============================] - 0s 10ms/step - loss: 1.8655 - accuracy: 0.2725 - val_loss: 1.7994 - val_accuracy: 0.5278
# Epoch 3/100
# 11/11 [==============================] - 0s 11ms/step - loss: 1.6199 - accuracy: 0.3862 - val_loss: 1.3508 - val_accuracy: 0.5903
# Epoch 4/100
# 11/11 [==============================] - 0s 10ms/step - loss: 1.2845 - accuracy: 0.5269 - val_loss: 0.8027 - val_accuracy: 0.8472
# Epoch 5/100
# 11/11 [==============================] - 0s 11ms/step - loss: 0.8260 - accuracy: 0.7006 - val_loss: 0.5079 - val_accuracy: 0.8889
# Epoch 6/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.6387 - accuracy: 0.7395 - val_loss: 0.3639 - val_accuracy: 0.9375
# Epoch 7/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.4267 - accuracy: 0.8533 - val_loss: 0.2306 - val_accuracy: 0.9444
# Epoch 8/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.3129 - accuracy: 0.8892 - val_loss: 0.1593 - val_accuracy: 0.9583
# Epoch 9/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.2530 - accuracy: 0.9192 - val_loss: 0.1380 - val_accuracy: 0.9722
# Epoch 10/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.2361 - accuracy: 0.9281 - val_loss: 0.1237 - val_accuracy: 0.9792
# Epoch 11/100
# 11/11 [==============================] - 0s 11ms/step - loss: 0.1678 - accuracy: 0.9431 - val_loss: 0.1095 - val_accuracy: 0.9792
# Epoch 12/100
# 11/11 [==============================] - 0s 11ms/step - loss: 0.1604 - accuracy: 0.9431 - val_loss: 0.0840 - val_accuracy: 0.9792
# Epoch 13/100
# 11/11 [==============================] - 0s 11ms/step - loss: 0.2046 - accuracy: 0.9192 - val_loss: 0.0785 - val_accuracy: 0.9861
# Epoch 14/100
# 11/11 [==============================] - 0s 11ms/step - loss: 0.1405 - accuracy: 0.9641 - val_loss: 0.0826 - val_accuracy: 0.9861
# Epoch 15/100
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0839 - accuracy: 0.9850 - val_loss: 0.0533 - val_accuracy: 0.9861
# Epoch 16/100
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0952 - accuracy: 0.9701 - val_loss: 0.0532 - val_accuracy: 0.9861
# Epoch 17/100
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0943 - accuracy: 0.9731 - val_loss: 0.0352 - val_accuracy: 0.9931
# Epoch 18/100
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0971 - accuracy: 0.9760 - val_loss: 0.0317 - val_accuracy: 0.9931
# Epoch 19/100
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0869 - accuracy: 0.9820 - val_loss: 0.0350 - val_accuracy: 0.9931
# Epoch 20/100
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0777 - accuracy: 0.9820 - val_loss: 0.0458 - val_accuracy: 0.9931
# Epoch 21/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0720 - accuracy: 0.9760 - val_loss: 0.0313 - val_accuracy: 0.9861
# Epoch 22/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0542 - accuracy: 0.9820 - val_loss: 0.0223 - val_accuracy: 1.0000
# Epoch 23/100
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0645 - accuracy: 0.9790 - val_loss: 0.0182 - val_accuracy: 1.0000
# Epoch 24/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0591 - accuracy: 0.9820 - val_loss: 0.0370 - val_accuracy: 0.9861
# Epoch 25/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0533 - accuracy: 0.9850 - val_loss: 0.0251 - val_accuracy: 0.9861
# Epoch 26/100
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0416 - accuracy: 0.9880 - val_loss: 0.0215 - val_accuracy: 0.9931
# Epoch 27/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0352 - accuracy: 0.9880 - val_loss: 0.0178 - val_accuracy: 0.9931
# Epoch 28/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0283 - accuracy: 0.9910 - val_loss: 0.0265 - val_accuracy: 0.9931
# Epoch 29/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0322 - accuracy: 0.9850 - val_loss: 0.0247 - val_accuracy: 0.9861
# Epoch 30/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0433 - accuracy: 0.9910 - val_loss: 0.0323 - val_accuracy: 0.9861
# Epoch 31/100
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0414 - accuracy: 0.9910 - val_loss: 0.0228 - val_accuracy: 0.9931
# Epoch 32/100
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0211 - accuracy: 0.9970 - val_loss: 0.0186 - val_accuracy: 0.9931
# Epoch 32: early stopping

# %%
#evaluate score
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.018596267327666283
# Test accuracy: 0.9930555820465088

# %%
model.save('/content/drive/MyDrive/demo_detection_face.hs5')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.

# %%
labels = ['phong', 'chi', 'TUAN', 'BINH', 'NHuy', 'Tri', 'Tu']

# %%
import matplotlib.pyplot as plt
from keras.utils import load_img, img_to_array
img = load_img('/content/drive/MyDrive/demo_detection_face.hs5/tu1.jpg')
plt.imshow(img)
plt.show()

# %%
from matplotlib import pyplot as plt
img = load_img(r'/content/drive/MyDrive/demo_detection_face.hs5/tu1.jpg', target_size=(30, 40))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1, 30, 40, 3)
img = img.astype('float32') / 255
result = labels[np.argmax(model.predict(img))]
print(result)
# Out:
# 1/1 [==============================] - 0s 89ms/step
# Tu

# %%
from keras.models import load_model
model = load_model('/content/drive/MyDrive/demo_detection_face.hs5')

# %%
from matplotlib import pyplot as plt
img = load_img(r'/content/drive/MyDrive/demo_detection_face.hs5/tu1.jpg', target_size=(30, 40))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1, 30, 40, 3)
img = img.astype('float32') / 255
result = labels[np.argmax(model.predict(img))]
print(result)
# Out:
# 1/1 [==============================] - 0s 139ms/step
# Tu

# %%
from keras.models import load_model
model = load_model('/content/drive/MyDrive/demo_detection_face.hs5')
from matplotlib import pyplot as plt
img = load_img(r'/content/drive/MyDrive/demo_detection_face.hs5/tu1.jpg', target_size=(30, 40))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1, 30, 40, 3)
img = img.astype('float32') / 255
result = labels[np.argmax(model.predict(img))]
print(result)
# Out:
# 1/1 [==============================] - 0s 85ms/step
# Tu

# %%
from matplotlib import pyplot as plt
img = load_img(r'/content/drive/MyDrive/demo_detection_face.hs5/tu.jpg', target_size=(30, 40))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1, 30, 40, 3)
img = img.astype('float32') / 255
result = labels[np.argmax(model.predict(img))]
print(result)
# Out:
# 1/1 [==============================] - 0s 48ms/step
# TUAN

# %%
from matplotlib import pyplot as plt
img = load_img(r'/content/drive/MyDrive/demo_detection_face.hs5/binh.jpg', target_size=(30, 40))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1, 30, 40, 3)
img = img.astype('float32') / 255
result = labels[np.argmax(model.predict(img))]
print(result)
# Out:
# 1/1 [==============================] - 0s 66ms/step
# BINH
